# %% [markdown]
# # Studio Machine — Strava EDA
#
# This notebook explores exported Strava activity data for the first version of Studio Machine.
#
# Initial goals:
# - Load and inspect Strava activity data
# - Clean important columns
# - Analyze weekly mileage and activity trends
# - Explore pace, heart rate, and consistency
# - Prepare data for future coaching recommendations
